# %%
import pandas as pd
df=pd.read_csv("set_a_timing.csv")
df
# Out:
#                               fname  cycle sound  location
# 0    set_a/normal__201102081321.wav      1    S1     10021
# 1    set_a/normal__201102081321.wav      1    S2     20759
# 2    set_a/normal__201102081321.wav      2    S1     35075
# 3    set_a/normal__201102081321.wav      2    S2     47244
# 4    set_a/normal__201102081321.wav      3    S1     62992
# ..                              ...    ...   ...       ...
# 385  set_a/normal__201108011118.wav     10    S2    284673
# 386  set_a/normal__201108011118.wav     11    S1    300863
# 387  set_a/normal__201108011118.wav     11    S2    314279
# 388  set_a/normal__201108011118.wav     12    S1    330980
# 389  set_a/normal__201108011118.wav     12    S2    343126
#
# [390 rows x 4 columns]

# %%
xd=df.groupby(['fname','sound'])
xd.first()
# Out:
#                                       cycle  location
# fname                          sound
# set_a/normal__201102081321.wav S1         1     10021
#                                S2         1     20759
# set_a/normal__201102260502.wav S1         1     11526
#                                S2         1     27941
# set_a/normal__201103090635.wav S1         1      5366
#                                S2         1     17632
# set_a/normal__201103140132.wav S1         1     16358
#                                S2         1     29272
# set_a/normal__201103140822.wav S1         1      3444
#                                S2         1     18080
# set_a/normal__201103151912.wav S1         1      3244
#                                S2         1     12053
# set_a/normal__201103221214.wav S1         1     27831
#                                S2         1     39095
# set_a/normal__201104141251.wav S1         1     21189
#                                S2         1     32879
# ...

# %%
df1=pd.read_csv(r"C:\Users\utfu\Downloads\Heart Sound Classification\xd.csv")
df1
# Out:
#      Unnamed: 0                               WAV  CATEGORY
# 0             0    set_a/normal__201101070538.wav    normal
# 1             1    set_a/normal__201101151127.wav    normal
# 2             2    set_a/normal__201102081152.wav    normal
# 3             3    set_a/normal__201102081321.wav    normal
# 4             4    set_a/normal__201102201230.wav    normal
# ..          ...                               ...       ...
# 580          14  set_a/extrahls__201103200218.wav  extrahls
# 581          15  set_a/extrahls__201104021355.wav  extrahls
# 582          16  set_a/extrahls__201104140118.wav  extrahls
# 583          17  set_a/extrahls__201104270458.wav  extrahls
# 584          18  set_a/extrahls__201104270459.wav  extrahls
#
# [585 rows x 3 columns]
